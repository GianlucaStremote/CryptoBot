# %%
import ccxt
import pandas as pd
import ta
import time
from datetime import datetime
import os
import csv
from concurrent.futures import ThreadPoolExecutor
import discord
from discord import Intents
import asyncio

# %%
# Configurações do bot
DISCORD_TOKEN = ''
CHANNEL_ID = ''  # Insira o ID do canal

intents = discord.Intents.default()
client = discord.Client(intents=intents)

@client.event
async def on_ready():
    print(f'Bot conectado como {client.user}')

async def send_discord_notification(message):
    channel = client.get_channel(CHANNEL_ID)
    if channel:
        await channel.send(message)
    else:
        print("Canal não encontrado")

def start_discord_bot():
    loop = asyncio.get_event_loop()
    loop.create_task(client.start(DISCORD_TOKEN))

# Iniciar o bot do Discord em segundo plano
start_discord_bot()

# %%
# Função para obter dados de preço em tempo real para um symbol específico
def fetch_real_time_data(exchange, symbol, timeframe, limit=100):
    ohlcv = exchange.fetch_ohlcv(symbol, timeframe=timeframe, limit=limit)
    data = pd.DataFrame(ohlcv, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
    data['timestamp'] = pd.to_datetime(data['timestamp'], unit='ms')
    data.set_index('timestamp', inplace=True)
    return data

# %%
# Função para calcular indicadores técnicos
def calculate_indicators(data):
    data['RSI'] = ta.momentum.RSIIndicator(data['close'], window=14).rsi()
    macd = ta.trend.MACD(data['close'])
    data['MACD'] = macd.macd()
    data['MACD_Signal'] = macd.macd_signal()
    data['SMA_50'] = ta.trend.SMAIndicator(data['close'], window=50).sma_indicator()
    data['SMA_200'] = ta.trend.SMAIndicator(data['close'], window=200).sma_indicator()
    bb = ta.volatility.BollingerBands(data['close'], window=20)
    data['Upper_BB'] = bb.bollinger_hband()
    data['Middle_BB'] = bb.bollinger_mavg()
    data['Lower_BB'] = bb.bollinger_lband()
    return data

# %% [markdown]
# ```
# # Detectar divergência entre RSI e preço
# def detect_divergence(data):
#     divergences = []
#     for i in range(1, len(data) - 1):
#         if data['close'].iloc[i] < data['close'].iloc[i - 1] and data['RSI'].iloc[i] > data['RSI'].iloc[i - 1]:
#             divergences.append(('Bullish', data.index.iloc[i]))
#         elif data['close'].iloc[i] > data['close'].iloc[i - 1] and data['RSI'].iloc[i] < data['RSI'].iloc[i - 1]:
#             divergences.append(('Bearish', data.index.iloc[i]))
#     return divergences

# %%
def detect_divergence(data, symbol):
    divergences = []
    log_data = []  # Lista para armazenar os dados de depuração
    threshold_timestamp = pd.Timestamp('2024-06-10 00:00:00')
    
    for i in range(1, len(data) - 1):
        # Verificar se o Timestamp atual é maior ou igual ao threshold
        if data.index[i] >= threshold_timestamp:
            # Verificar se os valores de preço e RSI não são 'nan'
            if pd.notna(data['close'].iloc[i]) and pd.notna(data['RSI'].iloc[i]):
                for j in range(i):
                    if pd.notna(data['close'].iloc[j]) and pd.notna(data['RSI'].iloc[j]):
                        # Divergência de alta
                        if data['RSI'].iloc[i] > data['RSI'].iloc[j] and data['close'].iloc[i] < data['close'].iloc[j]:
                            divergences.append(('Bullish', data.index[i]))
                            message_test = (f"Symbol: {symbol}, "
                                            f"Timestamp antigo: {data.index[j]}, Preco antigo: {data['close'].iloc[j]}, RSI antigo: {data['RSI'].iloc[j]}, "
                                            f"Timestamp atual: {data.index[i]}, Preco atual: {data['close'].iloc[i]}, RSI atual: {data['RSI'].iloc[i]}")
                            print(message_test)
                            break  # Encontrou uma divergência, não precisa continuar verificando para este índice

                        # Divergência de baixa
                        elif data['RSI'].iloc[i] < data['RSI'].iloc[j] and data['close'].iloc[i] > data['close'].iloc[j]:
                            divergences.append(('Bearish', data.index[i]))
                            break  # Encontrou uma divergência, não precisa continuar verificando para este índice

                # Armazenar os dados de depuração na lista
                log_data.append({
                    'SYMBOL': symbol,
                    'PRECO_ANTIGO': data['close'].iloc[i - 1],
                    'PRECO_ATUAL': data['close'].iloc[i],
                    'RSI_ANTIGO': data['RSI'].iloc[i - 1],
                    'RSI_ATUAL': data['RSI'].iloc[i],
                    'TIMESTAMP_ANTIGO': data.index[i - 1],
                    'TIMESTAMP_ATUAL': data.index[i]
                })

    # Converter a lista de dados de depuração em um DataFrame
    log_df = pd.DataFrame(log_data)
    
    # Definir o caminho do arquivo CSV
    file_path = 'divergence_log.csv'
    
    # Verificar se o arquivo já existe e definir o modo de escrita e cabeçalho
    write_header = not os.path.isfile(file_path)
    
    # Escrever os dados no arquivo CSV
    with open(file_path, mode='a', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=['SYMBOL', 'PRECO_ANTIGO', 'PRECO_ATUAL', 'RSI_ANTIGO', 'RSI_ATUAL', 'TIMESTAMP_ANTIGO', 'TIMESTAMP_ATUAL'], delimiter=';')
        if write_header:
            writer.writeheader()
        for row in log_data:
            writer.writerow(row)
    
    return divergences

# %%
# Função para verificar condições de compra e venda
def check_signals(data, symbol):
    signals = []
    
    for i in range(len(data)):
        signal = {}
        signal['Date'] = data.index[i]
        signal['Close'] = data.iloc[i]['close']

        divergences = detect_divergence(data.iloc[:i + 1], symbol)  # Detectar divergências
        # Condições RSI
        #if data.iloc[i]['RSI'] < 30:
        #    signal['RSI_Signal'] = 'Buy'
        #elif data.iloc[i]['RSI'] > 70:
        #    signal['RSI_Signal'] = 'Sell'
        #else:
        #    signal['RSI_Signal'] = 'Hold'
            
        # RSI Divergence Signal
        #divergences = detect_divergence(data)
        #if divergences:
        #    last_divergence = divergences[-1]
        #    if last_divergence[0] == 'Bullish':
        #        signals['RSI_Signal'] = 'Buy'
        #    elif last_divergence[0] == 'Bearish':
        #        signals['RSI_Signal'] = 'Sell'
        #    else:
        #        signal['RSI_Signal'] = 'Hold'     


        # Condições RSI baseadas na divergência
        #divergences = detect_divergence(data.iloc[:i + 1])
        #if divergences:
        #    last_divergence = divergences.iloc[-1]
        #    if last_divergence.iloc[0] == 'Bullish':
        #        signal['RSI_Signal'] = 'Buy'
        #    elif last_divergence.iloc[0] == 'Bearish':
        #        signal['RSI_Signal'] = 'Sell'
        #else:
        #    signal['RSI_Signal'] = 'Hold'
            
        # Incorporar divergências detectadas
        #for divergence in divergences:
        #    if divergence[1] == data.index[i]:
        #        if divergence[0] == 'Bullish':
        #            signal['RSI_Signal'] = 'Buy'
        #        elif divergence[0] == 'Bearish':
        #            signal['RSI_Signal'] = 'Sell'
        #        break
        #else:
        #    signal['RSI_Signal'] = 'None'

        if divergences:
            last_divergence = divergences[-1]
            if last_divergence[0] == 'Bullish' and last_divergence[1] == data.index[i]:
                signal['RSI_Signal'] = 'Buy'
            elif last_divergence[0] == 'Bearish' and last_divergence[1] == data.index[i]:
                signal['RSI_Signal'] = 'Sell'
            else:
                signal['RSI_Signal'] = 'Hold'
        else:
            signal['RSI_Signal'] = 'None'
        
       # Imprimir valores do RSI para análise
       # print(f"Symbol: {symbol}, Timestamp: {data.index[i]}, Close Price: {data.iloc[i]['close']}, RSI: {data.iloc[i]['RSI']}, last_div: {last_divergence}")
        
        # Condições MACD
        if data.iloc[i]['MACD'] > data.iloc[i]['MACD_Signal']:
            signal['MACD_Signal'] = 'Buy'
        else:
            signal['MACD_Signal'] = 'Sell'

        # Condições Médias Móveis
        if data.iloc[i]['SMA_50'] > data.iloc[i]['SMA_200']:
            signal['SMA_Signal'] = 'Buy'
        else:
            signal['SMA_Signal'] = 'Sell'

        # Condições Bandas de Bollinger
        if data.iloc[i]['close'] < data.iloc[i]['Lower_BB']:
            signal['BB_Signal'] = 'Buy'
        elif data.iloc[i]['close'] > data.iloc[i]['Upper_BB']:
            signal['BB_Signal'] = 'Sell'
        else:
            signal['BB_Signal'] = 'Hold'

        signals.append(signal)
    return pd.DataFrame(signals)

# %%
def process_symbols_group(exchange, symbols):
    for symbol in symbols:
        try:
            data = fetch_real_time_data(exchange, symbol, timeframe='4h', limit=100)
            data = calculate_indicators(data)
            signals = check_signals(data, symbol)
            signals['Symbol'] = symbol  # Adicionar o nome do symbol ao DataFrame de sinais
            latest_signals = signals.tail(1)

            
            # Verificar se pelo menos 2 dos 4 sinais são 'Buy', sendo RSI obrigatoriamente 'Buy' e os outros dois não 'Sell'
            buy_count = sum(signal == 'Buy' for signal in latest_signals[['RSI_Signal', 'MACD_Signal', 'SMA_Signal', 'BB_Signal']].values.flatten())
            rsi_signal = latest_signals['RSI_Signal'].values[0]
            other_signals = latest_signals[['MACD_Signal', 'SMA_Signal', 'BB_Signal']].values.flatten()

            
            timestamp = pd.Timestamp.now()
            price = latest_signals['Close'].values[0]
            message = (f"Sinais de compra (RSI: {rsi_signal}, MACD: {latest_signals['MACD_Signal'].values[0]}, "
                       f"SMA: {latest_signals['SMA_Signal'].values[0]}, BB: {latest_signals['BB_Signal'].values[0]}) para {symbol}.\n"
                       f"Timestamp: {timestamp}\nPreço atual: {price}")
                
            #print(message)
            #if buy_count >= 2 and rsi_signal == 'Buy' and all(signal != 'Sell' for signal in other_signals):
            if rsi_signal == 'Buy':    
                timestamp = pd.Timestamp.now()
                price = latest_signals['Close'].values[0]
                message = (f"Sinais de compra (RSI: {rsi_signal}, MACD: {latest_signals['MACD_Signal'].values[0]}, "
                           f"SMA: {latest_signals['SMA_Signal'].values[0]}, BB: {latest_signals['BB_Signal'].values[0]}) para {symbol}.\n"
                           f"Timestamp: {timestamp}\nPreço atual: {price}")
                
                print(message)
                asyncio.run_coroutine_threadsafe(send_discord_notification(message), client.loop)
            
            # Verificar se pelo menos 2 dos 4 sinais são 'Sell', sendo RSI obrigatoriamente 'Sell' e os outros dois não 'Buy'
            #sell_count = sum(signal == 'Sell' for signal in latest_signals[['RSI_Signal', 'MACD_Signal', 'SMA_Signal', 'BB_Signal']].values.flatten())
            #rsi_signal_sell = latest_signals['RSI_Signal'].values[0]
            #other_signals_sell = latest_signals[['MACD_Signal', 'SMA_Signal', 'BB_Signal']].values.flatten()
            #if sell_count >= 2 and rsi_signal_sell == 'Sell' and all(signal != 'Buy' for signal in other_signals_sell):
            elif rsi_signal == 'Sell':
                timestamp_sell = pd.Timestamp.now()
                price_sell = latest_signals['Close'].values[0]
                message_sell = (f"Sinais de compra (RSI: {rsi_signal}, MACD: {latest_signals['MACD_Signal'].values[0]}, "
                                f"SMA: {latest_signals['SMA_Signal'].values[0]}, BB: {latest_signals['BB_Signal'].values[0]}) para {symbol}.\n"
                                f"Timestamp: {timestamp_sell}\nPreço atual: {price_sell}")
            
                print(message_sell)
                asyncio.run_coroutine_threadsafe(send_discord_notification(message_sell), client.loop)
        except Exception as e:
            print(f"Erro ao processar {symbol}: {e}")

# %%
# Função principal para executar a análise em grupos de symbols usando múltiplas threads
def main():
    # Criar uma instância da exchange (por exemplo, Binance)
    exchange = ccxt.binance()

    # Obter todos os symbols disponíveis na exchange que terminam com 'USDT'
    markets = exchange.load_markets()
    #symbols = [symbol for symbol in markets.keys() if symbol.endswith('USDT')]
    symbols = [symbol for symbol in markets.keys() if symbol == 'ETH/USDT']

    # Definir o tamanho do grupo de symbols por thread
    group_size = 25

    # Dividir a lista de symbols em grupos
    symbol_groups = [symbols[i:i + group_size] for i in range(0, len(symbols), group_size)]

    while True:  # Loop infinito para executar continuamente
        print("Inicio de varredura.")
        with ThreadPoolExecutor(max_workers=len(symbol_groups)) as executor:
            futures = [executor.submit(process_symbols_group, exchange, group) for group in symbol_groups]
            for future in futures:
                future.result()
        
        # Aguardar 5 minutos antes de verificar novamente
        print("Varredura completa. Aguardando próximo ciclo.")
        time.sleep(300)  # 300 segundos = 5 minutos

# Executar a função principal
main()
# Out:
# Inicio de varredura.
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 04:00:00, Preco atual: 3647.79, RSI atual: 31.197479029629363
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 04:00:00, Preco atual: 3647.79, RSI atual: 31.197479029629363
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 08:00:00, Preco atual: 3675.95, RSI atual: 39.57795453014536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 04:00:00, Preco atual: 3647.79, RSI atual: 31.197479029629363
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 08:00:00, Preco atual: 3675.95, RSI atual: 39.57795453014536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-10 12:00:00, Preco atual: 3702.54, RSI atual: 46.23708450404254
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 04:00:00, Preco atual: 3647.79, RSI atual: 31.197479029629363
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 08:00:00, Preco atual: 3675.95, RSI atual: 39.57795453014536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-10 12:00:00, Preco atual: 3702.54, RSI atual: 46.23708450404254
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 16:00:00, Preco atual: 3668.33, RSI atual: 40.111954481280755
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 04:00:00, Preco atual: 3647.79, RSI atual: 31.197479029629363
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 08:00:00, Preco atual: 3675.95, RSI atual: 39.57795453014536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-10 12:00:00, Preco atual: 3702.54, RSI atual: 46.23708450404254
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 16:00:00, Preco atual: 3668.33, RSI atual: 40.111954481280755
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 20:00:00, Preco atual: 3667.85, RSI atual: 40.03182301585772
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 04:00:00, Preco atual: 3647.79, RSI atual: 31.197479029629363
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 08:00:00, Preco atual: 3675.95, RSI atual: 39.57795453014536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-10 12:00:00, Preco atual: 3702.54, RSI atual: 46.23708450404254
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 16:00:00, Preco atual: 3668.33, RSI atual: 40.111954481280755
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 20:00:00, Preco atual: 3667.85, RSI atual: 40.03182301585772
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 00:00:00, Preco atual: 3595.6, RSI atual: 30.239509644643945
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 04:00:00, Preco atual: 3647.79, RSI atual: 31.197479029629363
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 08:00:00, Preco atual: 3675.95, RSI atual: 39.57795453014536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-10 12:00:00, Preco atual: 3702.54, RSI atual: 46.23708450404254
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 16:00:00, Preco atual: 3668.33, RSI atual: 40.111954481280755
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 20:00:00, Preco atual: 3667.85, RSI atual: 40.03182301585772
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 00:00:00, Preco atual: 3595.6, RSI atual: 30.239509644643945
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 04:00:00, Preco atual: 3647.79, RSI atual: 31.197479029629363
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 08:00:00, Preco atual: 3675.95, RSI atual: 39.57795453014536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-10 12:00:00, Preco atual: 3702.54, RSI atual: 46.23708450404254
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 16:00:00, Preco atual: 3668.33, RSI atual: 40.111954481280755
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 20:00:00, Preco atual: 3667.85, RSI atual: 40.03182301585772
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 00:00:00, Preco atual: 3595.6, RSI atual: 30.239509644643945
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 04:00:00, Preco atual: 3647.79, RSI atual: 31.197479029629363
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 08:00:00, Preco atual: 3675.95, RSI atual: 39.57795453014536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-10 12:00:00, Preco atual: 3702.54, RSI atual: 46.23708450404254
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 16:00:00, Preco atual: 3668.33, RSI atual: 40.111954481280755
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 20:00:00, Preco atual: 3667.85, RSI atual: 40.03182301585772
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 00:00:00, Preco atual: 3595.6, RSI atual: 30.239509644643945
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 04:00:00, Preco atual: 3647.79, RSI atual: 31.197479029629363
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 08:00:00, Preco atual: 3675.95, RSI atual: 39.57795453014536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-10 12:00:00, Preco atual: 3702.54, RSI atual: 46.23708450404254
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 16:00:00, Preco atual: 3668.33, RSI atual: 40.111954481280755
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 20:00:00, Preco atual: 3667.85, RSI atual: 40.03182301585772
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 00:00:00, Preco atual: 3595.6, RSI atual: 30.239509644643945
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 16:00:00, Preco atual: 3497.21, RSI atual: 29.096521791090197
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 04:00:00, Preco atual: 3647.79, RSI atual: 31.197479029629363
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 08:00:00, Preco atual: 3675.95, RSI atual: 39.57795453014536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-10 12:00:00, Preco atual: 3702.54, RSI atual: 46.23708450404254
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 16:00:00, Preco atual: 3668.33, RSI atual: 40.111954481280755
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 20:00:00, Preco atual: 3667.85, RSI atual: 40.03182301585772
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 00:00:00, Preco atual: 3595.6, RSI atual: 30.239509644643945
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 16:00:00, Preco atual: 3497.21, RSI atual: 29.096521791090197
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 20:00:00, Preco atual: 3497.33, RSI atual: 29.119524833928097
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 04:00:00, Preco atual: 3647.79, RSI atual: 31.197479029629363
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 08:00:00, Preco atual: 3675.95, RSI atual: 39.57795453014536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-10 12:00:00, Preco atual: 3702.54, RSI atual: 46.23708450404254
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 16:00:00, Preco atual: 3668.33, RSI atual: 40.111954481280755
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 20:00:00, Preco atual: 3667.85, RSI atual: 40.03182301585772
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 00:00:00, Preco atual: 3595.6, RSI atual: 30.239509644643945
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 16:00:00, Preco atual: 3497.21, RSI atual: 29.096521791090197
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 20:00:00, Preco atual: 3497.33, RSI atual: 29.119524833928097
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 00:00:00, Preco atual: 3509.99, RSI atual: 31.63929776579745
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 04:00:00, Preco atual: 3647.79, RSI atual: 31.197479029629363
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 08:00:00, Preco atual: 3675.95, RSI atual: 39.57795453014536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-10 12:00:00, Preco atual: 3702.54, RSI atual: 46.23708450404254
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 16:00:00, Preco atual: 3668.33, RSI atual: 40.111954481280755
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 20:00:00, Preco atual: 3667.85, RSI atual: 40.03182301585772
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 00:00:00, Preco atual: 3595.6, RSI atual: 30.239509644643945
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 16:00:00, Preco atual: 3497.21, RSI atual: 29.096521791090197
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 20:00:00, Preco atual: 3497.33, RSI atual: 29.119524833928097
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 00:00:00, Preco atual: 3509.99, RSI atual: 31.63929776579745
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 04:00:00, Preco atual: 3526.71, RSI atual: 34.92938164751527
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 04:00:00, Preco atual: 3647.79, RSI atual: 31.197479029629363
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 08:00:00, Preco atual: 3675.95, RSI atual: 39.57795453014536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-10 12:00:00, Preco atual: 3702.54, RSI atual: 46.23708450404254
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 16:00:00, Preco atual: 3668.33, RSI atual: 40.111954481280755
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 20:00:00, Preco atual: 3667.85, RSI atual: 40.03182301585772
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 00:00:00, Preco atual: 3595.6, RSI atual: 30.239509644643945
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 16:00:00, Preco atual: 3497.21, RSI atual: 29.096521791090197
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 20:00:00, Preco atual: 3497.33, RSI atual: 29.119524833928097
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 00:00:00, Preco atual: 3509.99, RSI atual: 31.63929776579745
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 04:00:00, Preco atual: 3526.71, RSI atual: 34.92938164751527
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 08:00:00, Preco atual: 3531.72, RSI atual: 35.92450870789689
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 04:00:00, Preco atual: 3647.79, RSI atual: 31.197479029629363
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 08:00:00, Preco atual: 3675.95, RSI atual: 39.57795453014536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-10 12:00:00, Preco atual: 3702.54, RSI atual: 46.23708450404254
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 16:00:00, Preco atual: 3668.33, RSI atual: 40.111954481280755
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 20:00:00, Preco atual: 3667.85, RSI atual: 40.03182301585772
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 00:00:00, Preco atual: 3595.6, RSI atual: 30.239509644643945
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 16:00:00, Preco atual: 3497.21, RSI atual: 29.096521791090197
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 20:00:00, Preco atual: 3497.33, RSI atual: 29.119524833928097
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 00:00:00, Preco atual: 3509.99, RSI atual: 31.63929776579745
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 04:00:00, Preco atual: 3526.71, RSI atual: 34.92938164751527
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 08:00:00, Preco atual: 3531.72, RSI atual: 35.92450870789689
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-12 12:00:00, Preco atual: 3618.32, RSI atual: 50.12342184565968
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 04:00:00, Preco atual: 3647.79, RSI atual: 31.197479029629363
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 08:00:00, Preco atual: 3675.95, RSI atual: 39.57795453014536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-10 12:00:00, Preco atual: 3702.54, RSI atual: 46.23708450404254
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 16:00:00, Preco atual: 3668.33, RSI atual: 40.111954481280755
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 20:00:00, Preco atual: 3667.85, RSI atual: 40.03182301585772
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 00:00:00, Preco atual: 3595.6, RSI atual: 30.239509644643945
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 16:00:00, Preco atual: 3497.21, RSI atual: 29.096521791090197
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 20:00:00, Preco atual: 3497.33, RSI atual: 29.119524833928097
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 00:00:00, Preco atual: 3509.99, RSI atual: 31.63929776579745
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 04:00:00, Preco atual: 3526.71, RSI atual: 34.92938164751527
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 08:00:00, Preco atual: 3531.72, RSI atual: 35.92450870789689
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-12 12:00:00, Preco atual: 3618.32, RSI atual: 50.12342184565968
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 16:00:00, Preco atual: 3529.01, RSI atual: 40.22390006783536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 04:00:00, Preco atual: 3647.79, RSI atual: 31.197479029629363
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 08:00:00, Preco atual: 3675.95, RSI atual: 39.57795453014536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-10 12:00:00, Preco atual: 3702.54, RSI atual: 46.23708450404254
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 16:00:00, Preco atual: 3668.33, RSI atual: 40.111954481280755
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 20:00:00, Preco atual: 3667.85, RSI atual: 40.03182301585772
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 00:00:00, Preco atual: 3595.6, RSI atual: 30.239509644643945
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 16:00:00, Preco atual: 3497.21, RSI atual: 29.096521791090197
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 20:00:00, Preco atual: 3497.33, RSI atual: 29.119524833928097
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 00:00:00, Preco atual: 3509.99, RSI atual: 31.63929776579745
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 04:00:00, Preco atual: 3526.71, RSI atual: 34.92938164751527
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 08:00:00, Preco atual: 3531.72, RSI atual: 35.92450870789689
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-12 12:00:00, Preco atual: 3618.32, RSI atual: 50.12342184565968
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 16:00:00, Preco atual: 3529.01, RSI atual: 40.22390006783536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-12 20:00:00, Preco atual: 3560.12, RSI atual: 44.347201777629465
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 04:00:00, Preco atual: 3647.79, RSI atual: 31.197479029629363
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 08:00:00, Preco atual: 3675.95, RSI atual: 39.57795453014536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-10 12:00:00, Preco atual: 3702.54, RSI atual: 46.23708450404254
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 16:00:00, Preco atual: 3668.33, RSI atual: 40.111954481280755
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 20:00:00, Preco atual: 3667.85, RSI atual: 40.03182301585772
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 00:00:00, Preco atual: 3595.6, RSI atual: 30.239509644643945
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 16:00:00, Preco atual: 3497.21, RSI atual: 29.096521791090197
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 20:00:00, Preco atual: 3497.33, RSI atual: 29.119524833928097
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 00:00:00, Preco atual: 3509.99, RSI atual: 31.63929776579745
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 04:00:00, Preco atual: 3526.71, RSI atual: 34.92938164751527
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 08:00:00, Preco atual: 3531.72, RSI atual: 35.92450870789689
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-12 12:00:00, Preco atual: 3618.32, RSI atual: 50.12342184565968
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 16:00:00, Preco atual: 3529.01, RSI atual: 40.22390006783536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-12 20:00:00, Preco atual: 3560.12, RSI atual: 44.347201777629465
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-13 00:00:00, Preco atual: 3503.0, RSI atual: 39.02454721385122
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 04:00:00, Preco atual: 3647.79, RSI atual: 31.197479029629363
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 08:00:00, Preco atual: 3675.95, RSI atual: 39.57795453014536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-10 12:00:00, Preco atual: 3702.54, RSI atual: 46.23708450404254
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 16:00:00, Preco atual: 3668.33, RSI atual: 40.111954481280755
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 20:00:00, Preco atual: 3667.85, RSI atual: 40.03182301585772
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 00:00:00, Preco atual: 3595.6, RSI atual: 30.239509644643945
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 16:00:00, Preco atual: 3497.21, RSI atual: 29.096521791090197
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 20:00:00, Preco atual: 3497.33, RSI atual: 29.119524833928097
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 00:00:00, Preco atual: 3509.99, RSI atual: 31.63929776579745
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 04:00:00, Preco atual: 3526.71, RSI atual: 34.92938164751527
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 08:00:00, Preco atual: 3531.72, RSI atual: 35.92450870789689
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-12 12:00:00, Preco atual: 3618.32, RSI atual: 50.12342184565968
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 16:00:00, Preco atual: 3529.01, RSI atual: 40.22390006783536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-12 20:00:00, Preco atual: 3560.12, RSI atual: 44.347201777629465
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-13 00:00:00, Preco atual: 3503.0, RSI atual: 39.02454721385122
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-13 04:00:00, Preco atual: 3507.53, RSI atual: 39.64325073494679
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 04:00:00, Preco atual: 3647.79, RSI atual: 31.197479029629363
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 08:00:00, Preco atual: 3675.95, RSI atual: 39.57795453014536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-10 12:00:00, Preco atual: 3702.54, RSI atual: 46.23708450404254
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 16:00:00, Preco atual: 3668.33, RSI atual: 40.111954481280755
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 20:00:00, Preco atual: 3667.85, RSI atual: 40.03182301585772
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 00:00:00, Preco atual: 3595.6, RSI atual: 30.239509644643945
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 16:00:00, Preco atual: 3497.21, RSI atual: 29.096521791090197
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 20:00:00, Preco atual: 3497.33, RSI atual: 29.119524833928097
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 00:00:00, Preco atual: 3509.99, RSI atual: 31.63929776579745
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 04:00:00, Preco atual: 3526.71, RSI atual: 34.92938164751527
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 08:00:00, Preco atual: 3531.72, RSI atual: 35.92450870789689
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-12 12:00:00, Preco atual: 3618.32, RSI atual: 50.12342184565968
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 16:00:00, Preco atual: 3529.01, RSI atual: 40.22390006783536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-12 20:00:00, Preco atual: 3560.12, RSI atual: 44.347201777629465
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-13 00:00:00, Preco atual: 3503.0, RSI atual: 39.02454721385122
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-13 04:00:00, Preco atual: 3507.53, RSI atual: 39.64325073494679
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-13 08:00:00, Preco atual: 3497.17, RSI atual: 38.67670315515054
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 04:00:00, Preco atual: 3647.79, RSI atual: 31.197479029629363
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 08:00:00, Preco atual: 3675.95, RSI atual: 39.57795453014536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-10 12:00:00, Preco atual: 3702.54, RSI atual: 46.23708450404254
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 16:00:00, Preco atual: 3668.33, RSI atual: 40.111954481280755
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 20:00:00, Preco atual: 3667.85, RSI atual: 40.03182301585772
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 00:00:00, Preco atual: 3595.6, RSI atual: 30.239509644643945
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 16:00:00, Preco atual: 3497.21, RSI atual: 29.096521791090197
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 20:00:00, Preco atual: 3497.33, RSI atual: 29.119524833928097
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 00:00:00, Preco atual: 3509.99, RSI atual: 31.63929776579745
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 04:00:00, Preco atual: 3526.71, RSI atual: 34.92938164751527
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 08:00:00, Preco atual: 3531.72, RSI atual: 35.92450870789689
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-12 12:00:00, Preco atual: 3618.32, RSI atual: 50.12342184565968
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 16:00:00, Preco atual: 3529.01, RSI atual: 40.22390006783536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-12 20:00:00, Preco atual: 3560.12, RSI atual: 44.347201777629465
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-13 00:00:00, Preco atual: 3503.0, RSI atual: 39.02454721385122
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-13 04:00:00, Preco atual: 3507.53, RSI atual: 39.64325073494679
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-13 08:00:00, Preco atual: 3497.17, RSI atual: 38.67670315515054
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-13 12:00:00, Preco atual: 3441.73, RSI atual: 33.91181065851086
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 04:00:00, Preco atual: 3647.79, RSI atual: 31.197479029629363
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 08:00:00, Preco atual: 3675.95, RSI atual: 39.57795453014536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-10 12:00:00, Preco atual: 3702.54, RSI atual: 46.23708450404254
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 16:00:00, Preco atual: 3668.33, RSI atual: 40.111954481280755
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 20:00:00, Preco atual: 3667.85, RSI atual: 40.03182301585772
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 00:00:00, Preco atual: 3595.6, RSI atual: 30.239509644643945
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 16:00:00, Preco atual: 3497.21, RSI atual: 29.096521791090197
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 20:00:00, Preco atual: 3497.33, RSI atual: 29.119524833928097
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 00:00:00, Preco atual: 3509.99, RSI atual: 31.63929776579745
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 04:00:00, Preco atual: 3526.71, RSI atual: 34.92938164751527
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 08:00:00, Preco atual: 3531.72, RSI atual: 35.92450870789689
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-12 12:00:00, Preco atual: 3618.32, RSI atual: 50.12342184565968
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 16:00:00, Preco atual: 3529.01, RSI atual: 40.22390006783536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-12 20:00:00, Preco atual: 3560.12, RSI atual: 44.347201777629465
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-13 00:00:00, Preco atual: 3503.0, RSI atual: 39.02454721385122
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-13 04:00:00, Preco atual: 3507.53, RSI atual: 39.64325073494679
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-13 08:00:00, Preco atual: 3497.17, RSI atual: 38.67670315515054
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-13 12:00:00, Preco atual: 3441.73, RSI atual: 33.91181065851086
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-13 16:00:00, Preco atual: 3481.43, RSI atual: 39.645875291712535
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 04:00:00, Preco atual: 3647.79, RSI atual: 31.197479029629363
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 08:00:00, Preco atual: 3675.95, RSI atual: 39.57795453014536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-10 12:00:00, Preco atual: 3702.54, RSI atual: 46.23708450404254
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 16:00:00, Preco atual: 3668.33, RSI atual: 40.111954481280755
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 20:00:00, Preco atual: 3667.85, RSI atual: 40.03182301585772
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 00:00:00, Preco atual: 3595.6, RSI atual: 30.239509644643945
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 16:00:00, Preco atual: 3497.21, RSI atual: 29.096521791090197
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 20:00:00, Preco atual: 3497.33, RSI atual: 29.119524833928097
# ...
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-16 12:00:00, Preco atual: 3591.88, RSI atual: 57.18356222524134
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-16 16:00:00, Preco atual: 3599.03, RSI atual: 58.09626664877498
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-16 20:00:00, Preco atual: 3624.41, RSI atual: 61.253605398080474
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-17 00:00:00, Preco atual: 3582.05, RSI atual: 53.94745748005926
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-17 04:00:00, Preco atual: 3552.68, RSI atual: 49.53573585220768
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-17 08:00:00, Preco atual: 3527.63, RSI atual: 46.07483338517443
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-17 12:00:00, Preco atual: 3497.26, RSI atual: 42.223210657275814
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-17 16:00:00, Preco atual: 3554.01, RSI atual: 50.543019081953304
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-17 20:00:00, Preco atual: 3511.46, RSI atual: 45.27837369903648
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-18 00:00:00, Preco atual: 3441.53, RSI atual: 38.23038413763431
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-18 04:00:00, Preco atual: 3443.97, RSI atual: 38.58957683955735
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-18 08:00:00, Preco atual: 3414.11, RSI atual: 35.842707086947115
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-18 12:00:00, Preco atual: 3424.01, RSI atual: 37.43287978080523
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-18 16:00:00, Preco atual: 3423.27, RSI atual: 37.35834360934166
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-18 20:00:00, Preco atual: 3483.42, RSI atual: 46.65626477994646
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-19 00:00:00, Preco atual: 3565.93, RSI atual: 56.24943103267265
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-19 04:00:00, Preco atual: 3544.3, RSI atual: 53.53159443023209
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-19 08:00:00, Preco atual: 3536.94, RSI atual: 52.600273865311706
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-19 12:00:00, Preco atual: 3529.29, RSI atual: 51.59549815436114
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-19 16:00:00, Preco atual: 3546.29, RSI atual: 53.71154825977147
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-19 20:00:00, Preco atual: 3560.51, RSI atual: 55.46532318140947
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 00:00:00, Preco atual: 3684.14, RSI atual: 37.41824276400563
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 04:00:00, Preco atual: 3647.79, RSI atual: 31.197479029629363
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 08:00:00, Preco atual: 3675.95, RSI atual: 39.57795453014536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-10 12:00:00, Preco atual: 3702.54, RSI atual: 46.23708450404254
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 16:00:00, Preco atual: 3668.33, RSI atual: 40.111954481280755
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-10 20:00:00, Preco atual: 3667.85, RSI atual: 40.03182301585772
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 00:00:00, Preco atual: 3595.6, RSI atual: 30.239509644643945
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 16:00:00, Preco atual: 3497.21, RSI atual: 29.096521791090197
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-11 20:00:00, Preco atual: 3497.33, RSI atual: 29.119524833928097
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 00:00:00, Preco atual: 3509.99, RSI atual: 31.63929776579745
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 04:00:00, Preco atual: 3526.71, RSI atual: 34.92938164751527
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 08:00:00, Preco atual: 3531.72, RSI atual: 35.92450870789689
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-12 12:00:00, Preco atual: 3618.32, RSI atual: 50.12342184565968
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-12 16:00:00, Preco atual: 3529.01, RSI atual: 40.22390006783536
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-12 20:00:00, Preco atual: 3560.12, RSI atual: 44.347201777629465
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-13 00:00:00, Preco atual: 3503.0, RSI atual: 39.02454721385122
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-13 04:00:00, Preco atual: 3507.53, RSI atual: 39.64325073494679
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-13 08:00:00, Preco atual: 3497.17, RSI atual: 38.67670315515054
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-13 12:00:00, Preco atual: 3441.73, RSI atual: 33.91181065851086
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-13 16:00:00, Preco atual: 3481.43, RSI atual: 39.645875291712535
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-13 20:00:00, Preco atual: 3469.4, RSI atual: 38.55425683339173
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-14 00:00:00, Preco atual: 3490.91, RSI atual: 41.648025811285535
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-14 04:00:00, Preco atual: 3516.61, RSI atual: 45.19834308056923
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-14 08:00:00, Preco atual: 3515.8, RSI atual: 45.105194819234704
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-14 12:00:00, Preco atual: 3462.41, RSI atual: 39.34888391537756
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-14 16:00:00, Preco atual: 3406.21, RSI atual: 34.37574213750395
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-14 20:00:00, Preco atual: 3481.8, RSI atual: 44.53041726939186
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-15 00:00:00, Preco atual: 3504.4, RSI atual: 47.162922219898384
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-15 04:00:00, Preco atual: 3529.61, RSI atual: 50.01277493790627
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-15 08:00:00, Preco atual: 3539.4, RSI atual: 51.115455522277635
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-15 12:00:00, Preco atual: 3565.8, RSI atual: 54.05853160796049
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-15 16:00:00, Preco atual: 3558.48, RSI atual: 53.10387330595529
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-15 20:00:00, Preco atual: 3568.74, RSI atual: 54.321506405117745
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-16 00:00:00, Preco atual: 3555.01, RSI atual: 52.362187573458755
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-16 04:00:00, Preco atual: 3561.93, RSI atual: 53.27690127857389
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-16 08:00:00, Preco atual: 3555.28, RSI atual: 52.2388302891699
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-16 12:00:00, Preco atual: 3591.88, RSI atual: 57.18356222524134
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-16 16:00:00, Preco atual: 3599.03, RSI atual: 58.09626664877498
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-16 20:00:00, Preco atual: 3624.41, RSI atual: 61.253605398080474
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-17 00:00:00, Preco atual: 3582.05, RSI atual: 53.94745748005926
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-17 04:00:00, Preco atual: 3552.68, RSI atual: 49.53573585220768
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-17 08:00:00, Preco atual: 3527.63, RSI atual: 46.07483338517443
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-17 12:00:00, Preco atual: 3497.26, RSI atual: 42.223210657275814
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-17 16:00:00, Preco atual: 3554.01, RSI atual: 50.543019081953304
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-17 20:00:00, Preco atual: 3511.46, RSI atual: 45.27837369903648
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-18 00:00:00, Preco atual: 3441.53, RSI atual: 38.23038413763431
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-18 04:00:00, Preco atual: 3443.97, RSI atual: 38.58957683955735
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-18 08:00:00, Preco atual: 3414.11, RSI atual: 35.842707086947115
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-18 12:00:00, Preco atual: 3424.01, RSI atual: 37.43287978080523
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-07 16:00:00, Preco antigo: 3687.37, RSI antigo: 28.8145029406287, Timestamp atual: 2024-06-18 16:00:00, Preco atual: 3423.27, RSI atual: 37.35834360934166
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-18 20:00:00, Preco atual: 3483.42, RSI atual: 46.65626477994646
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-19 00:00:00, Preco atual: 3565.93, RSI atual: 56.24943103267265
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-19 04:00:00, Preco atual: 3544.3, RSI atual: 53.53159443023209
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-19 08:00:00, Preco atual: 3536.94, RSI atual: 52.600273865311706
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-19 12:00:00, Preco atual: 3529.29, RSI atual: 51.59549815436114
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-19 16:00:00, Preco atual: 3546.29, RSI atual: 53.71154825977147
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-19 20:00:00, Preco atual: 3560.51, RSI atual: 55.46532318140947
# Symbol: ETH/USDT, Timestamp antigo: 2024-06-06 16:00:00, Preco antigo: 3791.01, RSI antigo: 43.431291369825686, Timestamp atual: 2024-06-20 00:00:00, Preco atual: 3553.65, RSI atual: 54.39462663072635
# Varredura completa. Aguardando próximo ciclo.
